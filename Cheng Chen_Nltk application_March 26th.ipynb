# %% [markdown]
# # CSCE670::Information storage and retrivial
# # Spotlight of NLTK toolkit
# NLTK is a high efficiency platcorm for building python programs and it easy easier to work with human language data pocessing. It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries for classification, tokenization, stemming, tagging, parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries, and an active discussion forum. It is also called “a wonderful tool for teaching, and working in, computational linguistics using Python,” and “an amazing library to play with natural language.”
#
#
# <a href="http://www.nltk.org/book/">Natural Language Processing with Python</a> provides a practical introduction to programming for language processing. Written by the creators of NLTK, it guides the reader through the fundamentals of writing Python programs, working with corpora, categorizing text, analyzing linguistic structure, and more. The online version of the book has been been updated for Python 3 and NLTK 3.
#
# It has comprehensive API file and programming of natural language topic function, which makes NLTK welcome to language researcher, engineering, teacher, student and some industry users. NLTK can be used in windows, Linux, Mac OS system and it is an open source free project.
#
# # The breif introduction of NLTK setting on Mac/Unix
# the python's version should be 2.7 or over 3.2
#
# 1.install nltk: sudo pip install -U nltk
#
# 2.install numpy: sudo pip install -U numpy
#
# 3.test: run python, and then import nltk in the environment

# %% [markdown]
# # NLTK has many dictionary resources that can help us a lot in processing document, here are some examples of nltk resources.
#
# # 1.FreqDist inheritents dict so we can operate FreqDist like a dictionary object, in this example, FreqDist's key is word and value is the total frequency the word

# %%
import nltk
from nltk.book import *
freqdist = FreqDist(text1)
for key in freqdist:
    print(key, freqdist[key])
# Out:
# [ 3
# Moby 84
# Dick 84
# by 1137
# Herman 1
# Melville 1
# 1851 3
# ] 1
# ETYMOLOGY 1
# . 6862
# ( 210
# Supplied 2
# a 4569
# Late 1
# Consumptive 1
# Usher 2
# to 4542
# Grammar 2
# School 1
# ) 78
# The 612
# pale 18
# -- 1070
# threadbare 1
# in 3916
# coat 28
# , 18713
# heart 90
# body 110
# and 6024
# brain 37
# ; 4072
# I 2124
# see 253
# him 1058
# now 646
# He 230
# was 1632
# ever 203
# dusting 2
# his 2459
# old 436
# lexicons 1
# grammars 2
# with 1659
# queer 44
# handkerchief 5
# mockingly 1
# embellished 3
# all 1462
# the 13721
# gay 13
# flags 1
# of 6536
# known 80
# nations 12
# world 173
# loved 3
# dust 10
# it 2209
# somehow 43
# mildly 10
# reminded 4
# mortality 1
# " 1478
# While 30
# you 841
# take 118
# hand 205
# school 9
# others 37
# teach 5
# them 471
# what 442
# name 69
# whale 906
# - 2552
# fish 133
# is 1695
# be 1030
# called 116
# our 199
# tongue 11
# leaving 38
# out 529
# through 227
# ignorance 10
# letter 12
# H 2
# which 640
# almost 186
# ...

# %%
import nltk
from nltk.book import *
freqdist = FreqDist(text1)
freqdist.plot(10)
print("Above is the graph that shows the rank of the frequency for the given number of words ")
# Out:
# Above is the graph that shows the rank of the frequency for the given number of words

# %% [markdown]
# FreqDist()::most_common(n) return the most common  n items list

# %%
import nltk
from nltk.book import *
freqdist = FreqDist(text1)
freqdist.most_common(15)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124)]

# %% [markdown]
# # 2.In nltk there is a name resource set which includes two documents of men's name and women's name respectively.

# %%
name=nltk.corpus.names
print(name.fileids())
malename=name.words('male.txt')
femalename=name.words('female.txt')
print([w for w in malename if w in femalename])
# Out:
# ['female.txt', 'male.txt']
# ...

# %% [markdown]
# # 3. There is a stopwords set that we can use to process file, and we can also add some words and remove words as we want.

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('English'))

#add words 
new_stopwords = ['Tiger', 'mouse', 'monkey']
new_stopwords_list = stop_words.union(new_stopwords)

#remove words 
not_stopwords = {'and', 'ne'} 
final_stop_words = set([word for word in new_stopwords_list if word not in not_stopwords])

print(final_stop_words)
# Out:
# {'ve', 'how', 'd', 'hasn', 'why', 'you', 'isn', "she's", 'while', 'we', 'ours', 'aren', 'ain', 'on', 'by', 'am', 'whom', 'up', 'her', "don't", 'for', 'myself', 'some', 'being', 'mightn', 'against', 'are', 'then', "weren't", 'both', 'no', "mightn't", "shouldn't", 'him', 'shouldn', 'same', 'all', 'i', 're', 'haven', 'nor', 'such', 'wouldn', 'were', 'where', 'should', 'been', 'monkey', 'my', 'down', "haven't", 'very', 'because', 'do', 'through', 'further', 'which', 'be', 'into', 'does', 'or', 's', 'than', 'more', "didn't", 'themselves', 'only', 'ma', 'hadn', 'our', 'so', 'the', 'just', 'won', 'there', 'shan', "you've", 'm', 'me', 'below', 'your', "aren't", 'if', 'don', 'have', 'had', 'couldn', 'is', 'doing', 'during', 'now', 'over', 'can', 'yourself', 'here', "wouldn't", 'it', "you're", 'once', 'until', 'didn', 'a', "it's", 'at', 'above', 'each', "wasn't", 'this', "hadn't", 'these', "won't", "mustn't", "shan't", 'under', 'has', 'few', 'in', 'they', 'yours', 'when', 'not', "hasn't", 'wer
# ...

# %% [markdown]
# # 4.Tokenization is very important since we have to use tokenization to process a text, which means split a text into small parts. NLTK is an excellent tool to tokenize text, usually we split a text into sentences and then split the sentence into words. Below is the example of tokenization of homework1 data set

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
with open( 'homework_1_data.txt' ) as f:
    raw = f.read()
    list_sentences=sent_tokenize(raw)
    list_words=set(word_tokenize(raw))
print(list_words)
# Out:
# {'international', '26445', '4443', '12752', 'quantative', '-intrigues', 'drastic', 'calculus', '28337', 'info-', '22365', 'happened', 'pairing', 'hunting', '14771', '26357', '3396', '11464', 'depended', '15989', 'dose', 'emanates', '24319', '13236', '611', '18287', 'cmds', '19945', 'overlaps', 'hyperplanes', 'semi-structured', '-keyboards', 'thought/creative', 'functionslity', 'corrected', '28490', '7066', '13680', '20424', '26773', '14392', '19993', '16946', 'rtsp', 'step', '6065', '21393', '21514', '23653', '18923', '23136', '28613', '9062', '30742', '12797', '10580', 'dark', '23265', '12470', 'g+', '13529', 'praising', 'converter', 'gather/make', 'hottest', '24073', 'x-ray', 'reliability', '13551', '∑', 'behaviors', 'rf', '20266', '2526', 'slowing', 'bonds', '26794', 'already-crawled', '4803', 'orbicularis', '12202', '-unit', '2995', 'striking', 'partially-loaded', '29383', 'technique', 'veiwed', '21998', '2195', '25006', '30693', '2231', 'suspicious', 'pg.9', '20314', '21128', '6
# ...

# %% [markdown]
# # 5.WordNet is a database which is built for natural language processing. It includes groups of synonyms and a brief definition.

# %%
from nltk.corpus import wordnet
syn = wordnet.synsets("NLP")
print(syn[0].definition())
syn = wordnet.synsets("Python")
print(syn[0].definition())
# Out:
# the branch of information science that deals with natural language information
# large Old World boas

# %% [markdown]
# # 6.NLTK has a class called PorterStemmer which uses Porter stemming algorithm.

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
print(stemmer.stem('parking'))
# Out:
# park

# %% [markdown]
# # we can also determine the location of a word in the text: how many words from the beginning it appears. This positional information can be displayed using a dispersion plot. Each stripe represents an instance of a word, and each row represents the entire text

# %%
#  from nltk.book import *
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America", "liberty", "constitution", "law", "politic"])

# %% [markdown]
# # Below is an example of Using nltk to analyze text and make a precise prediction on a new text, in this example, we have to use a simple training that is relevant to machine learning.

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.classify import NaiveBayesClassifier

text1 = 'I like this movie!'
text2 = 'That is a nice cake.'
text3 = 'This is a great idea.'
text4 = 'That is a really bad discussion.'
text5 = 'This is a terrible talk.'

def proc_text(text):
    rawwords = nltk.word_tokenize(text) 
    wordnet_lematizer = WordNetLemmatizer()    
    words = [wordnet_lematizer.lemmatize(rawword) for rawword in rawwords] 
    filtered_words = [word for word in words if word not in stopwords.words('english')]   
    return {word: True for word in filtered_words}
train_data = [[proc_text(text1), 1],
              [proc_text(text2), 1],
              [proc_text(text3), 1],
              [proc_text(text4), 0],
              [proc_text(text5), 0]]
nb_model = NaiveBayesClassifier.train(train_data)
text6 = 'Everything is good.'
print(nb_model.classify(proc_text(text6)))
# Out:
# 1

# %% [markdown]
# # Conclusion:
# NLTK is a comprehensive NLP toolkit and easy to install and operate. It includes a lot of functions that can be used in processing and analyzing a text, above are all some very common examples. With the help of it, we can also get a precise model of text and make a prediction on new text. In a long text, we can easily find specific data of the information we want and then process it.

# %% [markdown]
# # Reference:
# 1.<a href="http://www.nltk.org/book/">Natural Language Processing with Python</a>
#
# 2.<a href="https://likegeeks.com/nlp-tutorial-using-python-nltk/#NLP-Implementations">Natural Language Processing tutorial</a>
#
# 3.[NLP processing](https://www.nltk.org/book_1ed/ch01.html)
#
# 4.[sentimental analysis introduction](https://www.learndatasci.com/tutorials/sentiment-analysis-reddit-headlines-pythons-nltk/)
